# %%
# %tensorflow_version 1.x
# !pip install h5py==2.10.0
# Out:
# TensorFlow 1.x selected.
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 5.3 MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.15.0)
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed h5py-2.10.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd  /content/drive/'My Drive'/NLP_project/dataset
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/NLP_project/dataset

# %%
import pandas as pd
import re
from nltk import download
download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
data = pd.read_csv("news_summary_more.csv")
data = pd.read_csv("news_summary_more.csv", nrows=50000)
print(data.shape)
data.head()
# Out:
# (50000, 2)
#                                            headlines                                               text
# 0  upGrad learner switches to career in ML & Al w...  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Delhi techie wins free food from Swiggy for on...  Kunal Shah's credit card bill payment platform...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...  New Zealand defeated India by 8 wickets in the...
# 3  Aegon life iTerm insurance plan helps customer...  With Aegon Life iTerm Insurance plan, customer...
# 4  Have known Hirani for yrs, what if MeToo claim...  Speaking about the sexual harassment allegatio...

# %%
for i in range(5):
    print( str(i+1) + ": " + data.headlines[i])
    print("----------------------------------")
    print(data.text[i])
    print()
# Out:
# 1: upGrad learner switches to career in ML & Al with 90% salary hike
# ----------------------------------
# Saurav Kant, an alumnus of upGrad and IIIT-B's PG Program in Machine learning and Artificial Intelligence, was a Sr Systems Engineer at Infosys with almost 5 years of work experience. The program and upGrad's 360-degree career support helped him transition to a Data Scientist at Tech Mahindra with 90% salary hike. upGrad's Online Power Learning has powered 3 lakh+ careers.
#
# 2: Delhi techie wins free food from Swiggy for one year on CRED
# ----------------------------------
# Kunal Shah's credit card bill payment platform, CRED, gave users a chance to win free food from Swiggy for one year. Pranav Kaushik, a Delhi techie, bagged this reward after spending 2000 CRED coins. Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more.
#
# 3: New Zealand end Rohit Sharma-led India's 12-match winning streak
# ----------------------------------
# New Zealand defeated India by 8 wickets in the fourth ODI at Hamilton on Thursday to win their first match of the five-match ODI series. India lost an international match under Rohit Sharma's captaincy after 12 consecutive victories dating back to March 2018. The match witnessed India getting all out for 92, their seventh lowest total in ODI cricket history.
#
# 4: Aegon life iTerm insurance plan helps customers save tax
# ----------------------------------
# With Aegon Life iTerm Insurance plan, customers can enjoy tax benefits on your premiums paid and save up to â¹46,800^ on taxes. The plan provides life cover up to the age of 100 years. Also, customers have options to insure against Critical Illnesses, Disability and Accidental Death Benefit Rider with a life cover up to the age of 80 years.
#
# 5: Have known Hirani for yrs, what if MeToo claims are not true: Sonam
# ----------------------------------
# Speaking about the sexual harassment allegations against Rajkumar Hirani, Sonam Kapoor said, "I've known Hirani for many years...What if it's not true, the [#MeToo] movement will get derailed." "In the #MeToo movement, I always believe a woman. But in this case, we need to reserve our judgment," she added. Hirani has been accused by an assistant who worked in 'Sanju'.

# %%
CURRENCIES = { "$": "USD", "zł": "PLN", "£": "GBP", "¥": "JPY", "฿": "THB", "₡": "CRC", "₦": "NGN","₩": "KRW",
               "₪": "ILS", "₫": "VND", "€": "EUR", "₱": "PHP", "₲": "PYG", "₴": "UAH", "₹": "INR",}
CURRENCY_REGEX = re.compile("({})+".format("|".join(re.escape(c) for c in CURRENCIES.keys())))

EMAIL_REGEX = re.compile(
    r"(?:^|(?<=[^\w@.)]))([\w+-](\.(?!\.))?)*?[\w+-]@(?:\w-?)*?\w+(\.([a-z]{2,})){1,3}(?:$|(?=\b))",
    flags=re.IGNORECASE | re.UNICODE,)

# A list of contractions from http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                "you're": "you are", "you've": "you have", "i've": "i have"}

# %%
def clean_text(text, remove_stopwords):

    text = text.lower()
    text = text.split()
    clean_text = []
    for word in text:
        if word in contractions:
            clean_text.append(contractions[word])
        else:
            clean_text.append(word)
    text = " ".join(clean_text)

    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = EMAIL_REGEX.sub(' ',text)
    text = CURRENCY_REGEX.sub(' ',text)
    text = ' '.join([contractions[t] if t in contractions else t for t in text.split(" ")])
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
    text = re.sub(r"'s\b","", text)
    text = re.sub(r'&amp;', '', text)

    if remove_stopwords:
        text = text.split()
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
        text = " ".join(text)

    return text

# %%
cleaned_headlines = []
cleaned_text = []

for headlines in data['headlines']:
    cleaned_headlines.append(clean_text(headlines, remove_stopwords=False))
print("complete 1")

for text in data['text']:
    cleaned_text.append(clean_text(text, remove_stopwords=True))
print("complete 2")
# Out:
# complete 1
# complete 2

# %%
for i in range(5):
    print( str(i+1) + ": " + cleaned_headlines[i])
    print("----------------------------------")
    print(cleaned_text[i])
    print()
# Out:
# 1: upgrad learner switches to career in ml   al with 90  salary hike
# ----------------------------------
# saurav kant alumnus upgrad iiit b pg program machine learning artificial intelligence sr systems engineer infosys almost 5 years work experience program upgrad 360 degree career support helped transition data scientist tech mahindra 90 salary hike upgrad online power learning powered 3 lakh careers
#
# 2: delhi techie wins free food from swiggy for one year on cred
# ----------------------------------
# kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending 2000 cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit
#
# 3: new zealand end rohit sharma led india 12 match winning streak
# ----------------------------------
# new zealand defeated india 8 wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy 12 consecutive victories dating back march 2018 match witnessed india getting 92 seventh lowest total odi cricket history
#
# 4: aegon life iterm insurance plan helps customers save tax
# ----------------------------------
# aegon life iterm insurance plan customers enjoy tax benefits premiums paid save â¹46 800^ taxes plan provides life cover age 100 years also customers options insure critical illnesses disability accidental death benefit rider life cover age 80 years
#
# 5: have known hirani for yrs  what if metoo claims are not true  sonam
# ----------------------------------
# speaking sexual harassment allegations rajkumar hirani sonam kapoor said i've known hirani many years true metoo movement get derailed metoo movement always believe woman case need reserve judgment added hirani accused assistant worked 'sanju'

# %%
import matplotlib.pyplot as plt

text_word_count = []
headlines_word_count = []

for i in cleaned_text:
    text_word_count.append(len(i.split()))
for i in cleaned_headlines:
    headlines_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text': text_word_count, 'headlines': headlines_word_count})
length_df.hist(bins=15)
plt.show()

# %%
count = 0
for i in cleaned_text:
    if(len(i.split())<=1000):
        count += 1
print(count/len(cleaned_text))
# Out:
# 1.0

# %%
import numpy as np
max_headlines_len=15
max_text_len=55

cleaned_text = np.array(cleaned_text)
cleaned_headlines = np.array(cleaned_headlines)

short_text=[]
short_headlines=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_headlines[i].split())<=max_headlines_len and len(cleaned_text[i].split())<=max_text_len):
          short_text.append(cleaned_text[i])
          short_headlines.append(cleaned_headlines[i])

df=pd.DataFrame({'text':cleaned_text,'headlines':cleaned_headlines})
df['headlines'] = df['headlines'].apply(lambda x : 'sostok '+ x + ' eostok')

from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['headlines']),test_size=0.1,random_state=0,shuffle=True)

df.head()
# Out:
#                                                 text                                          headlines
# 0  saurav kant alumnus upgrad iiit b pg program m...  sostok upgrad learner switches to career in ml...
# 1  kunal shah credit card bill payment platform c...  sostok delhi techie wins free food from swiggy...
# 2  new zealand defeated india 8 wickets fourth od...  sostok new zealand end rohit sharma led india ...
# 3  aegon life iterm insurance plan customers enjo...  sostok aegon life iterm insurance plan helps c...
# 4  speaking sexual harassment allegations rajkuma...  sostok have known hirani for yrs  what if meto...

# %%
# %cd  /content/drive/'My Drive'/NLP_project
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

thresh=4
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value

print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt)
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr)
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

x_voc
# Out:
# /content/drive/My Drive/NLP_project
# Using TensorFlow backend.
# % of rare words in vocabulary: 61.58730661430539
# Total Coverage of rare words: 3.4417605459954417
# 24259

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

thresh=6
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value

print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt)
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr)
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val)

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_headlines_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_headlines_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# % of rare words in vocabulary: 73.11056443897772
# Total Coverage of rare words: 6.907015177497845
# (45000, 45000)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
from keras import backend as K
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model, model_from_json
from tensorflow.keras.callbacks import EarlyStopping
#!git clone https://github.com/ziadloo/attention_keras.git
#!pip install numpy==1.19.5
from att import AttentionLayer
K.clear_session()

latent_dim = 200
embedding_dim=110

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:Entity <bound method AttentionLayer.call of <att.AttentionLayer object at 0x7f9e31373b90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method AttentionLayer.call of <att.AttentionLayer object at 0x7f9e31373b90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 55)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 55, 110)      2668490     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 55, 200), (N 248800      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 55, 200), (N 320800      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 110)    865810      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 55, 200), (N 320800      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 200),  248800      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 200),  80200       lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 400)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 7871)   3156271     concat_layer[0][0]
# ==================================================================================================
# Total params: 7,909,971
# Trainable params: 7,909,971
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.load_weights("text_50.h5")

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 165s 4ms/sample - loss: 5.0909 - val_loss: 4.6941
# Epoch 2/50
# 45000/45000 [==============================] - 156s 3ms/sample - loss: 4.6413 - val_loss: 4.4153
# Epoch 3/50
# 45000/45000 [==============================] - 155s 3ms/sample - loss: 4.3943 - val_loss: 4.2375
# Epoch 4/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 4.2311 - val_loss: 4.1122
# Epoch 5/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 4.1019 - val_loss: 4.0156
# Epoch 6/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.9922 - val_loss: 3.9324
# Epoch 7/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.8994 - val_loss: 3.8677
# Epoch 8/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.8190 - val_loss: 3.8103
# Epoch 9/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.7434 - val_loss: 3.7599
# Epoch 10/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.6790 - val_loss: 3.7207
# Epoch 11/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.6174 - val_loss: 3.6807
# Epoch 12/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.5608 - val_loss: 3.6495
# Epoch 13/50
# 45000/45000 [==============================] - 156s 3ms/sample - loss: 3.5079 - val_loss: 3.6179
# Epoch 14/50
# 45000/45000 [==============================] - 156s 3ms/sample - loss: 3.4645 - val_loss: 3.5909
# Epoch 15/50
# 45000/45000 [==============================] - 156s 3ms/sample - loss: 3.4214 - val_loss: 3.5698
# Epoch 16/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.3810 - val_loss: 3.5503
# Epoch 17/50
# 45000/45000 [==============================] - 156s 3ms/sample - loss: 3.3422 - val_loss: 3.5251
# Epoch 18/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.3083 - val_loss: 3.5119
# Epoch 19/50
# 45000/45000 [==============================] - 156s 3ms/sample - loss: 3.2745 - val_loss: 3.4895
# Epoch 20/50
# 45000/45000 [==============================] - 154s 3ms/sample - loss: 3.2383 - val_loss: 3.4689
# Epoch 21/50
# 45000/45000 [==============================] - 155s 3ms/sample - loss: 3.2069 - val_loss: 3.4615
# Epoch 22/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.1779 - val_loss: 3.4421
# Epoch 23/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.1531 - val_loss: 3.4351
# Epoch 24/50
# 45000/45000 [==============================] - 156s 3ms/sample - loss: 3.1283 - val_loss: 3.4231
# Epoch 25/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.1042 - val_loss: 3.4152
# Epoch 26/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.0827 - val_loss: 3.4026
# Epoch 27/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.0607 - val_loss: 3.3940
# Epoch 28/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.0399 - val_loss: 3.3861
# Epoch 29/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.0183 - val_loss: 3.3707
# Epoch 30/50
# 45000/45000 [==============================] - 157s 3ms/sample - loss: 3.0003 - val_loss: 3.3653
# Epoch 31/50
#  9216/45000 [=====>........................] - ETA: 2:00 - loss: 2.9312

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# 2. Save Keras Model or weights on google drive

# create on Colab directory
model.save('my_model.h5')
model_file = drive.CreateFile({'title' : 'my_model.h5'})
model_file.SetContentFile('my_model.h5')
model_file.Upload()

# download to google drive
drive.CreateFile({'id': model_file.get('id')})
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 729, in _input_request
#     ident, reply = self.session.recv(self.stdin_socket, 0)
#   File "/usr/local/lib/python3.7/dist-packages/jupyter_client/session.py", line 803, in recv
#     msg_list = socket.recv_multipart(mode, copy=copy)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py", line 625, in recv_multipart
#     parts = [self.recv(flags, copy=copy, track=track)]
#   File "zmq/backend/cython/socket.pyx", line 781, in zmq.backend.cython.socket.Socket.recv
#   File "zmq/backend/cython/socket.pyx", line 817, in zmq.backend.cython.socket.Socket.recv
#   File "zmq/backend/cython/socket.pyx", line 186, in zmq.backend.cython.socket._recv_copy
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-18-cadb67d9a066>", line 7, in <module>
#     auth.authenticate_user()
#   File "/usr/local/lib/python3.7/dist-packages/google/colab/auth.py", line 153, in authenticate_user
#     _gcloud_login()
#   File "/usr/local/lib/python3.7/dist-packages/google/colab/auth.py", line 95, in _gcloud_login
#     code = get_code(prompt + ' ')
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 704, in raw_input
#     password=False,
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 734, in _input_request
#     raise KeyboardInterrupt
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'zmq/backend/cython/socket.pyx'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.7/inspect.py", line 1464, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 170, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "/usr/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/usr/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-cadb67d9a066> in <module>()
#       5
#       6 # 1. Authenticate and create the PyDrive client.
# ----> 7 auth.authenticate_user()
#       8 gauth = GoogleAuth()
#       9 gauth.credentials = GoogleCredentials.get_application_default()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/auth.py in authenticate_user(clear_output)
#     151     context_manager = _output.temporary if clear_output else _noop
#     152     with context_manager():
# --> 153       _gcloud_login()
#     154     _install_adc()
#     155     colab_tpu_addr = _os.environ.get('COLAB_TPU_ADDR', '')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/auth.py in _gcloud_login()
#      93     # https://github.com/jupyter/notebook/issues/3159
#      94     prompt = prompt.rstrip()
# ---> 95     code = get_code(prompt + ' ')
#      96     gcloud_process.communicate(code.strip())
#      97   finally:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-d3f7650c2e80> in <module>()
#       1 from matplotlib import pyplot
# ----> 2 pyplot.plot(history.history['loss'], label='train')
#       3 pyplot.plot(history.history['val_loss'], label='test')
#       4 pyplot.legend()
#       5 pyplot.show()
#
# NameError: name 'history' is not defined

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_headlines_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString
# Out:
# WARNING:tensorflow:Entity <bound method AttentionLayer.call of <att.AttentionLayer object at 0x7f9e31373b90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method AttentionLayer.call of <att.AttentionLayer object at 0x7f9e31373b90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method AttentionLayer.call of <att.AttentionLayer object at 0x7f9e31373b90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'

# %%
print(len(y_tr))
# Out:
# 45000

# %%
from nltk.translate.bleu_score import sentence_bleu
score_count = []
for i in range(0,len(y_tr)):
  Original = seq2summary(y_tr[i])
  Original_split = [Original.split()]
  Predicted = decode_sequence(x_tr[i].reshape(1,max_text_len))
  Predicted_split = Predicted.split()
  score_count.append(sentence_bleu(Original_split, Predicted_split, weights=(1, 0, 0, 0)))

length_df = pd.DataFrame({'score': score_count})
length_df.hist(bins=15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-03e84ef9e388> in <module>()
#       4   Original = seq2summary(y_tr[i])
#       5   Original_split = [Original.split()]
# ----> 6   Predicted = decode_sequence(x_tr[i].reshape(1,max_text_len))
#       7   Predicted_split = Predicted.split()
#       8   score_count.append(sentence_bleu(Original_split, Predicted_split, weights=(1, 0, 0, 0)))
#
# <ipython-input-25-4c1f81035378> in decode_sequence(input_seq)
#      43     while not stop_condition:
#      44
# ---> 45         output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
#      46
#      47         # Sample a token
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     906         max_queue_size=max_queue_size,
#     907         workers=workers,
# --> 908         use_multiprocessing=use_multiprocessing)
#     909
#     910   def reset_metrics(self):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/engine/training_arrays.py in predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     721         verbose=verbose,
#     722         steps=steps,
# --> 723         callbacks=callbacks)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     392
#     393         # Get outputs.
# --> 394         batch_outs = f(ins_batch)
#     395         if not isinstance(batch_outs, list):
#     396           batch_outs = [batch_outs]
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
from nltk.translate.bleu_score import sentence_bleu

for i in range(0,300):
    Original = seq2summary(y_tr[i])
    Original_split = [Original.split()]
    Predicted = decode_sequence(x_tr[i].reshape(1,max_text_len))
    Predicted_split = Predicted.split()
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("score: ", sentence_bleu(Original_split, Predicted_split, weights=(1, 0, 0, 0)))
    print("\n")
# Out:
# Review: man arrested stealing around 4 200 xiaomi phones company warehouse gurugram per initial investigation claimed total worth phones stolen â¹87 lakh report said accused accomplices stole phones apart appliances including washing machines products
# Original summary: man held for stealing xiaomi phones worth in gurugram
# Predicted summary:  man held for stealing mobile phone in atm
# score:  0.5515605641153721
#
#
# Review: applauding flipkart walmart deal paytm founder vijay shekhar sharma said perfect answer indian startups adding fellow startup guy happy deal took place sharma said good indian ecosystem walmart wednesday announced acquire 77 flipkart 16 billion
# Original summary: it is 1 lakh cr i call it perfect paytm founder on flipkart
# Predicted summary:  i am not a star in india ceo anil bansal flipkart deal
# score:  0.1533407357715539
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Review: aditya birla group promoted ultratech cement entered agreement binani industries buy cement arm â¹7 266 crore even insolvency process continues binani approached ultratech arranging funds pay debts exchange selling binani cement move reportedly aimed blocking decision hand binani dalmia bharat
# Original summary: to buy cement for over â¹7 200 crore
# Predicted summary:  fortis to buy stake in for 1st time in
# score:  0.3333333333333333
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Review: talking son taimur ali khan kareena kapoor khan said think taimur looks like father saif ali khan eyes look like japanese saif earlier said days looks like kareena days like looks like chinese version let us say
# Original summary: taimur looks like saif with eyes of japanese kareena
# Predicted summary:  kareena and i am a taimur taimur kareena
# score:  0.22062422564614886
#
#
# Review: supreme court thursday dismissed pil demanding immediate execution four death row convicts 2012 nirbhaya gangrape murder case kind prayer making apex court bench said petitioner alok srivastava plea said delay execution death penalty acting bad precedent nnn
# Original summary: sc rejects plea for early of nirbhaya convicts
# Predicted summary:  sc rejects plea for kathua rape victim death
# score:  0.5
#
#
# Review: jacob zuma resigned post south africa president defying 48 hour deadline given ruling african national congress leave office zuma face confidence vote parliament thursday said fear motion confidence life lost never divided name
# Original summary: s africa prez resigns after given 48 hours by ruling party
# Predicted summary:  sri lanka prez appointed as president
# score:  0.07243303475117972
#
#
# Review: remains missing american service members killed korean war arrived country us president donald trump thursday said hopes see north korean leader kim jong un soon surprised took kind action also thank nice letter added
# Original summary: looking forward to see kim jong un soon us prez trump
# Predicted summary:  trump calls kim jong un sister
# score:  0.28973213900471884
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Review: india patent office rejected plea last april canadian company patent citing sex toys violate public order morality law views sex toys negatively never engaged positively notion sexual pleasure office noted adding importing selling sex toys considered object hence illegal india
# Original summary: india rejected patent for sex toy saying it is
# Predicted summary:  india to sex sex abuse by sex abuse report
# score:  0.2222222222222222
#
#
# Review: air india celebrated first non stop flight amritsar birmingham 8 years flight dhol bhangra recently video celebration shows man dancing singing playing dhol passengers cheering terminal came alive indian dancers weaving way passengers birmingham airport said statement
# Original summary: bhangra performed in air india amritsar flight
# Predicted summary:  air india flight makes emergency landing
# score:  0.423240862445307
#
#
# Review: ajay bhushan pandey head aadhaar issuing authority uidai next revenue secretary hasmukh adhia retires november 30 pandey continue hold additional charge chief executive officer uidai chairman goods services tax network gstn orders 1984 maharashtra cadre ias officer pandey take december 1
# Original summary: uidai head ajay bhushan pandey to be next revenue secretary
# Predicted summary:  uidai to pay aadhaar for not paying for 7 months
# score:  0.2
#
#
# Review: pakistani sports presenter zainab abbas took twitter share picture actor irrfan khan watching england pakistan test lord pic shared actor irrfan khan enjoying match lord captioned picture user name ali claimed irrfan sitting front looked really weak
# Original summary: pak journo shares pic of irrfan watching match at lord
# Predicted summary:  pak ali khan apologises for pic of irrfan khan
# score:  0.39770636302860873
#
#
# Review: aiadmk launched day long hunger strike demanding setting cauvery management board photographs surfaced online showing party workers eating protest protest lasted 8 5 pm photographs reportedly taken vellore pudukkottai centre failed set board despite march 29 deadline
# Original summary: aiadmk workers eating during hunger strike
# Predicted summary:  tn govt orders to shut down after cauvery dispute
# score:  0
#
#
# Review: security personnel rescued 26 minor girls muzaffarpur bandra express tweet passenger july 5 passenger tweeted noticed girls crying looking uncomfortable officials varanasi lucknow took action rescued girls aged 10 14 years two men found girls aged 22 55
# Original summary: passenger tweet helps indian railways rescue 26 girls
# Predicted summary:  3 men help save from train girls in bihar
# score:  0.11111111111111109
#
#
# Review: 45 year old man died way hospital friday allegedly ambulance carrying ran oxygen uttar pradesh saharanpur hospital chief medical officer bs sodhi denied allegations family allegations seem false emergency medical technician says oxygen cylinder went empty end still inquire said
# Original summary: man dies after ambulance carrying him runs out of oxygen
# Predicted summary:  man dies after falling from up building building in up
# score:  0.3
#
#
# Review: responding question pm narendra modi meeting pakistani counterpart shahid khaqan abbasi ministry external affairs mea said two meet commonwealth heads government meeting thursday mea spokesperson raveesh kumar said meeting planned friday either pm modi attended london visit
# Original summary: no meeting between pm modi pak pm at mea
# Predicted summary:  india pak pm modi to visit india to meet pak pm modi
# score:  0.3333333333333333
#
#
# Review: talking advice given son shetty make bollywood debut suniel shetty said i've told honest work i've also told love producer one invests money films added suniel make debut hindi remake telugu film
# Original summary: told him to be honest with work suniel on son debut
# Predicted summary:  i am not a son of my son karan johar
# score:  0.09048374180359597
#
#
# Review: enforcement directorate attached 41 properties worth â¹1 217 2 crore belonging fraud accused gitanjali owner mehul choksi companies 170 acre park hyderabad worth â¹500 crore also attached assets include 15 flats 17 office premises shopping mall farmhouse alibaug 231 acres land maharashtra tamil nadu
# Original summary: choksi assets worth â¹1 including park seized
# Predicted summary:  ed attaches â¹10 000 crore assets worth â¹3 crore
# score:  0.2222222222222222
#
#
# Review: flipkart co founder binny bansal may exit indian e commerce giant walmart majority stake homegrown startup according reports sachin bansal binny bansal looking sell stake startup reports added earlier reports said walmart may retain key flipkart executives including ceo kalyan krishnamurthy deal
# Original summary: flipkart binny bansal to exit after walmart deal reports
# Predicted summary:  flipkart binny bansal to sell flipkart stake in flipkart reports
# score:  0.5
#
#
# Review: iran foreign minister javad zarif said chabahar port operational adding indian shipments afghanistan already gone port port opens trade route india central asia bypassing pakistan iran said soon hand port india operate ten years
# Original summary: chabahar port says iran foreign minister
# Predicted summary:  iran will not be a oil minister on iran oil imports
# score:  0.18181818181818182
#
#
# Review: special cell delhi police reportedly arrested three suspected members international drug cartel seized 30 kg heroin worth â¹120 crore trio used procure drugs supplier imphal smuggled drugs myanmar biggest quantity drug seized national capital year police claimed
# Original summary: 30 kg heroin worth â¹120 crore seized in delhi 3 arrested
# Predicted summary:  delhi police arrest held for stealing worth â¹2 crore
# score:  0.26691246763893595
#
#
# Review: greece monday established space organisation country first space agency effort reportedly aimed rebuilding economy establishment agency greece aims make gains various sectors including telecommunications defence medical applications agriculture among others digital policy said
# Original summary: greece its first space agency
# Predicted summary:  isro plans to launch space mission
# score:  0.16666666666666669
#
#
# Review: gold tiffin box weighing 2 kg cup spoon studded diamonds stolen nizam museum hyderabad police said monday police suspect burglar entered museum ventilator avoid caught bent cctv stolen reportedly used last nizam hyderabad
# Original summary: diamond gold box stolen from hyd museum
# Predicted summary:  gold worth stolen from police
# score:  0.40219202762138356
#
#
# Review: sunny leone took instagram announce birth twin boys named asher singh weber noah singh weber wrote june 21st 2017 day husband daniel weber found might possibly 3 children within short amount time speculated twins born via surrogacy
# Original summary: sunny leone announces birth of twin boys
# Predicted summary:  sunny leone announces birth of
# score:  0.6703200460356393
#
#
# Review: telephonic call friday world bank president jim yong kim congratulated prime minister narendra modi india rise ease business rankings kim described historic unprecedented achievement also said remarkable nation 1 25 billion people achieved rise 65 ranks four years
# Original summary: india rise in doing business index historic world bank to pm
# Predicted summary:  world bank to be a trillion economy in india ceo
# score:  0.45241870901797976
#
#
# Review: many four policemen killed militants opened fire guard post jammu shopian district tuesday three policemen died spot one succumbed injuries hospital per reports attack militants reportedly fled rifles belonging policemen n
# Original summary: 4 policemen killed in militant attack in jammu and kashmir
# Predicted summary:  2 killed in encounter in bihar in bihar
# score:  0.2920502936517768
#
#
# Review: least 16 people killed several others reported injured saturday lightning struck church rwanda district lightning hit 45 people praying church leaving 14 dead spot comes day lightning struck 18 students country killing one
# Original summary: 16 killed as lightning strikes church in africa rwanda
# Predicted summary:  16 killed in explosion at in rajasthan
# score:  0.32206169703226534
#
#
# Review: defending champions manchester city led 102 year old vera cohen 98 year old olga premier league match fulham vera regular manchester city matches 85 years attends matches olga son danny son law roger vera olga wore personalised manchester city jerseys ages written
# Original summary: 102 yr old 98 yr old fans lead out manchester city for pl match
# Predicted summary:  man utd beat arsenal 1 1 in a match as liverpool beat arsenal
# score:  0.07122777528017817
#
#
# Review: jd leader mathew thomas friday alleged civil aviation ministry give permission charter plane shift congress jd mlas karnataka kerala kerala tourism minister surendran earlier invited mlas state avoid horse trading poaching bjp mlas reportedly shifted hyderabad
# Original summary: aviation ministry denied plane to shift mlas jd s leader
# Predicted summary:  jd s govt to get off defence minister after rafale deal
# score:  0.2727272727272727
#
#
# Review: barcelona midfielder turan currently loan banned record 16 matches pushing insulting threatening turkish league match 31 year old sent assistant referee decision also handed â¹6 lakh fine 2015 turan thrown boot direction
# Original summary: barã§a handed record 16 match ban for
# Predicted summary:  player who scored 2 players in match for 1 months
# score:  0.2
#
#
# Review: listing reasons bjp loss kairana recent bypolls uttar pradesh party mla shyam prakash said farmers happy government corruption compared last government rise prakash also slammed state government facebook saying came power using pm narendra modi name
# Original summary: corruption is on a rise as compared to last govt bjp mla
# Predicted summary:  bjp mla quits as cabinet clears new party
# score:  0.22744899739223753
#
#
# Review: india former captain anil kumble said indian cricket team let former captain ms dhoni enjoy game team keep depending left enjoy game engage younger players finish games kumble said 37 year old cricketer
# Original summary: cannot keep on dhoni as a kumble
# Predicted summary:  dhoni is like a lot of the world cup kapil dev
# score:  0.18181818181818182
#
#
# Review: indian badminton players training hyderabad based pullela gopichand badminton academy receive premium eggs japanese food processing major foods move aimed enhancing dietary inputs players preparation 2020 olympics held japan company use antibiotics chickens produces eggs high nutrition
# Original summary: japan firm to supply for indian
# Predicted summary:  india to open world largest e commerce site
# score:  0.12500000000000003
#
#
# Review: 53 year old woman 32 year old daughter arrested monday allegedly duping around 130 people â¹5 crore mumbai duo would take money promising government flats people affected railway land expansion mumbai metropolitan region development authority road widening projects police said reportedly also used handover forged documents victims
# Original summary: mother daughter cheat 130 people of â¹5 crore in mumbai
# Predicted summary:  woman held for raping 2 year old in mumbai
# score:  0.19885318151430437
#
#
# Review: reference stephen hawking zero gravity experience nasa paid tribute late theoretical physicist tweeting may keep flying like superman hawking flew aboard zero gravity flight 2007 said true freedom superman minutes describing experience space station astronauts 2014
# Original summary: may you keep flying like superman nasa on stephen hawking
# Predicted summary:  hawking was a black hole in the world study
# score:  0.09942659075715217
#
#
# Review: indian steeplechase runner naveen dagar tested positive banned substance ahead upcoming asian games indonesia dagar bronze medal last asian games reportedly tested positive due dope test failure india go 3 000 metre race event asian games 2018
# Original summary: indian runner fails dope test before asian games
# Predicted summary:  india to get its first asian games in asian games
# score:  0.2
#
#
# Review: india seafood exports crossed 7 billion mark first time 2017 18 frozen fish continuing flagship export items exports fetched 7 08 billion compared 5 77 billion fy17 us south east asia retained positions major import markets india seafood products share 32 76 31 59 respectively
# Original summary: indiaâs exports cross 7 billion for the first time
# Predicted summary:  india trade deficit hits 3 5 bn in april
# score:  0
#
#
# Review: pm narendra modi rakhi sister devi saturday passed away jharkhand dhanbad age 103 last year devi son written pm modi desire tie rakhi wrist since brother passed away invited pm modi official residence celebrate raksha bandhan
# Original summary: pm modi rakhi sister devi passes away aged 103
# Predicted summary:  pm modi brother death of accident
# score:  0.2021768865708778
#
#
# Review: bradman hit first class career 100th hundred playing innings australian xi indian side november 15 1947 bradman hit 172 runs first innings becoming first australian score 100 first class centuries ton bradman last eight first class hundreds come losing cause
# Original summary: bradman 100th first class hundred came against an indian side
# Predicted summary:  1st class 10 innings came to go to score in 3 innings
# score:  0.16666666666666669
#
#
# Review: german payments firm overtaken country biggest bank deutsche bank market value monday whose market capitalisation stands 24 1 billion gets 5 much revenue deutsche bank 19 year old company revenues 1 7 billion last year processes credit card payments online retailers also facilitates smartphone payments
# Original summary: german payments firm worth more than deutsche bank
# Predicted summary:  bitcoin profit rises 10 to 5 billion in march quarter
# score:  0
#
#
# Review: iron rich rocks near ancient lake sites mars best place seek fossil evidence life likely existed four billion years ago researchers suggested scientists said sedimentary rocks made clay likely contain fossils rocks rich iron mineral called helps preserve fossils
# Original summary: scientists propose 'best on mars to look for fossils
# Predicted summary:  scientists find on mars mission to study
# score:  0.4294155960430205
#
#
# Review: talking box office success 'padmaavat' actress deepika padukone said numbers never moment feel proud artist individual added could better reward surpassed previous highs film recently became deepika highest ever grossing film india
# Original summary: numbers never i feel proud deepika on 'padmaavat'
# Predicted summary:  deepika padukone is the world no one person deepika
# score:  0.11111111111111109
#
#
# Review: reliance industries chairman mukesh ambani wednesday said data bad previous forms india data must controlled owned indians adding data fundamentally belongs individual billionaire said use monetise way share gains
# Original summary: india data must be controlled and owned by indians mukesh ambani
# Predicted summary:  india is not a great data of india mukesh ambani
# score:  0.36193496721438384
#
#
# Review: leaders congress' telangana unit gone 48 hour hunger strike suspension congress mlas expulsion two mlas protesting governor address meanwhile congress mlas also planning move high court suspension one mlas thrown headphone council head swamy damaged
# Original summary: t'gana cong goes on hunger strike against suspension
# Predicted summary:  cong workers protest against congress in k'taka
# score:  0.24767939992862334
#
#
# Review: reacting trailer sanjay dutt biopic 'sanju' sanjay dutt sister priya dutt said cannot anybody 100 per cent loved way ranbir kapoor portrayed life much comedy situation may seemed crazy look back laugh added
# Original summary: loved ranbir as sanjay dutt sister priya
# Predicted summary:  dutt is a dutt on 'sanju' in ranbir sanjay dutt
# score:  0.3
#
#
# Review: canadian pm justin trudeau said visit india photo opportunities rather close india canada ties also people people ties also cultural economic business many different ways engage added trudeau arrived india saturday week long visit
# Original summary: india visit not for photo ops it is for ties canadian pm
# Predicted summary:  india canada pm trudeau visits india
# score:  0.12262648039048077
#
#
# Review: 129 odis india pakistan faced india 52 pakistan emerged victorious 73 odis however asia cup tournament teams beaten five odis teams faced uae 26 odis pakistan winning 19
# Original summary: what are the odi head to head between ind pak
# Predicted summary:  pakistan odi series win vs pakistan in asia cup
# score:  0.09942659075715217
#
#
# Review: nearly â¹10 lakh crore wiped market capitalisation bse listed companies last 6 days bringing total market cap â¹145 lakh crore much â¹2 7 lakh crore wiped companies' value tuesday extending falling streak sixth straight session sensex fell points settle 34 195
# Original summary: â¹10 lakh crore wiped out from indian stocks in 6 days
# Predicted summary:  â¹1 crore loss in india biggest loss in 2018
# score:  0.17794164509262397
#
#
# Review: health ministry asked states ban electronic nicotine delivery systems ends including e cigarettes heat burn devices vape e hookah ministry said devices great health risk children adolescents pregnant women women reproductive age children non smokers using products could switch cigarettes get addicted nicotine added
# Original summary: centre asks states to ban e cigarettes e hookah
# Predicted summary:  govt asks states to ban on food e cigarettes
# score:  0.6666666666666666
#
#
# Review: confirming shraddha kapoor star choreographer filmmaker remo d'souza upcoming dance film 'abcd 3' katrina kaif exit varun dhawan posted picture shraddha tweeted shraddha bahut katrina spokesperson said decided step film dates clashing 'bharat' currently shooting
# Original summary: shraddha to star in varun dance film post katrina exit
# Predicted summary:  shraddha kapoor to star in varun katrina film reports
# score:  0.6959861353000654
#
#
# Review: pakistani rounder former captain mohammad hafeez announced retire test cricket end ongoing third final test match series pakistan new zealand abu dhabi announcing retirement feel happy worked hard career hafeez said stumps day 2
# Original summary: pak all rounder mohammad announces test retirement
# Predicted summary:  pak batsman once called me a test for 1st time
# score:  0.2
#
#
# Review: cauvery delta farmers association thursday staged protest blocked entrance tamil nadu secretariat demanding meeting cm edappadi k palaniswami farmers wanted discuss supreme court verdict 126 year old cauvery water sharing dispute reduced tamil nadu share also restricted movement deputy cm panneerselvam
# Original summary: farmers block tn secretariat over meeting with cm
# Predicted summary:  tn cm approves bharat bandh over cauvery water dispute
# score:  0.3333333333333333
#
#
# Review: priyanka chopra got engaged rumoured boyfriend american singer nick jonas 36th birthday july 18 get married october per reports celebrated birthday nick london priyanka nick made first public appearance together 2017 met gala reportedly started dating two months rumoured engagement
# Original summary: priyanka got engaged to nick last week to marry in oct reports
# Predicted summary:  priyanka nick to host wedding reception in reports
# score:  0.37908166232039586
#
#
# Review: talking modern startup investing silicon valley investor said middle enormous multi kind ponzi scheme adding investors pressurise startups well also said investors people writing cheques balance sheet people job people money
# Original summary: startup is a ponzi scheme silicon valley investor
# Predicted summary:  i am not a startup on co founder
# score:  0.25
#
#
# Review: delhi high court allowed freed house arrest activist gautam navlakha said true honest words power bullets adding freedom end navlakha among five activists put arrest connection bhima koregaon violence pune killed one person
# Original summary: honest word more powerful than bullet activist post release
# Predicted summary:  people who are not bail hc in delhi
# score:  0
#
#
# Review: jack co founder chinese e commerce giant alibaba said plans open institute indonesia train entrepreneurs field technology train 1 000 leaders year next 10 years added indonesia communications minister last month announced plans partner jack increase country exports
# Original summary: jack ma plans institute for tech in indonesia
# Predicted summary:  alibaba to train in train to train
# score:  0.12383969996431167
#
#
# Review: actor amitabh bachchan said consider failure able preserve writings late father poet harivansh rai bachchan absence father responsibility rises justice preservation life wrote blog
# Original summary: i will fail if i do not preserve my father says big b
# Predicted summary:  i am not a father of my daughter big b on b'day
# score:  0.46002220731466165
#
#
# Review: women iran shared videos dancing online show support arrested teenager iranian authorities arrested posted videos dancing instagram without wearing mandatory headscarf iranian state media released video acknowledged breaking moral norms
# Original summary: iranian women dance to show support for arrested teenager
# Predicted summary:  iran apologises for sex with dance in us
# score:  0.22062422564614886
#
#
# Review: two men posing policemen allegedly robbed 68 year old woman gold chain worth â¹60 000 mumbai woman claimed men wearing safari suits approached saying robbers area asked give jewellery said probably due gave chain
# Original summary: 2 men posing as cops rob mumbai woman of gold chain
# Predicted summary:  2 men men woman at woman for stealing arrested
# score:  0.26691246763893595
#
#
# Review: mumbai arthur road jail building dozen cells european uk prison standards house fugitive millionaires like vijay mallya challenged extradition citing poor jail conditions reports said cells meet human rights criteria expected completed six months built 800 prisoners arthur jail houses around 2 800 prisoners
# Original summary: uk style jail cells to be built for fugitive millionaires report
# Predicted summary:  uk pm to get jail in uk jail for uk
# score:  0.36193496721438384
#
#
# Review: amul 20 year old case ahmedabad based private dairy selling milk brand names shakti' products sounded similar amul products shakti' dairy argued names different amul accused copying colour scheme
# Original summary: amul wins 20 yr old case against dairy selling milk named
# Predicted summary:  fir against woman for stealing million
# score:  0.07243303475117972
#
#
# Review: russian president vladimir putin signed decree establishing new directorate russian army promote patriotism colonel general andrei russian army veteran previously served country conflict syria head directorate similar directorate existed soviet army ensure soldiers remained loyal ruling communist party
# Original summary: russia new army wing to promote
# Predicted summary:  putin putin putin to army on june 30
# score:  0.25
#
#
# Review: snapchat ceo evan spiegel revealed photo sharing app lost 2 191 million daily active users april june period due disruption caused redesign comes users complained app became confusing due redesign user loss first since company went public however revenue increased 44 year year 262 million
# Original summary: snapchat loses daily users for the first time over
# Predicted summary:  snapchat to launch its first ever in 2019
# score:  0.22062422564614886
#
#
# Review: winds blowing across antarctica ross ice shelf causes surface producing near constant set seismic according new research also found pitch seismic hum changed weather conditions altered surface kind like youâre blowing flute constantly ice shelf one researchers said
# Original summary: antarctic ice as blow across its surface
# Predicted summary:  scientists discover a new year
# score:  0
#
#
# Review: reacting tripura cm biplab deb remark civil engineers mechanical engineers go civil services twitter users started drawing similar using user wrote cats take cat exam another tweeted singh singers appear gate exam read another tweet
# Original summary: troll for civil engineer civil service remark
# Predicted summary:  tripura cm asks staff to sell for free employees
# score:  0.11111111111111109
#
#
# Review: aamir khan younger brother faisal khan feature upcoming film also mark debut singer surprised director suggested singing song insisted voice required number faisal said lent voice romantic track titled
# Original summary: aamir khan brother to make his singing debut
# Predicted summary:  aamir khan to play in debut film reports
# score:  0.5
#
#
# Review: cambridge analytica refuted report facebook accused firm attaining data 87 million users british firm claimed licensed data 30 million deleted data servers firm earlier accused exploiting user data meddle 2016 us presidential elections
# Original summary: firm accused of fb leak denies data of 87 mn users
# Predicted summary:  facebook ceo zuckerberg data scandal firm
# score:  0.14486606950235942
#
#
# Review: referring shiv sena chief uddhav thackeray speech maharashtra maharashtra navnirman sena mns leader sandeep deshpande said party give reward anyone speech 30 years since ayodhya incident still bjp says matter court hindus innocent fools thackeray said
# Original summary: shiv sena chief uddhav thackeray speech and win mns
# Predicted summary:  shiv sena slams mp sena over tweet on ram mandir
# score:  0.2
#
#
# Review: kartik aaryan bhumi pednekar ananya panday star upcoming remake 1978 film 'pati patni aur woh' confirming news ananya shared picture co stars film makers wrote super start roller coaster ride shooting film begin february per reports
# Original summary: kartik bhumi ananya to star in aur remake
# Predicted summary:  kartik aaryan to star in film reports
# score:  0.4953587998572467
#
#
# Review: private sector lender yes bank wednesday said non executive chairman ashok chawla resigned immediate effect chawla also chairman nse named cbi chargesheet related aircel maxis case former finance secretary also worked chairman competition commission india
# Original summary: yes bank chairman who was named in aircel maxis chargesheet quits
# Predicted summary:  yes bank appoints as ceo as chairman
# score:  0.24202205228903967
#
#
# Review: executive director nobel foundation said actions aung san suu kyi taken myanmar leader regrettable nobel peace prize withdrawn added made sense withdraw awards reaction things happened given
# Original summary: suu kyi actions will not withdraw prize nobel chief
# Predicted summary:  will not be able to be a nobel prize
# score:  0.4444444444444444
#
#
# Review: tata sons chairman n chandrasekaran expected present business viability plan proposed acquisition cash strapped jet airways board friday per reports move would tata third investment india aviation sector since launch airasia india vistara jet 124 aircraft fleet domestic market share 15 8
# Original summary: tata sons chief to pitch plan to buy jet airways to board report
# Predicted summary:  tata steel to buy jet airways stake in uk
# score:  0.35621132690553037
#
#
# Review: us automaker fiat chrysler filed patent violation complaint mahindra mahindra us international trade commission fiat alleged certain design features mahindra road utility vehicle roxor infringed intellectual property rights jeep design mahindra said fiat agreed 2009 never bring claims used grille approved
# Original summary: fiat files patent violation case against mahindra
# Predicted summary:  us firm files patent for mahindra to patent infringement
# score:  0.3333333333333333
#
#
# Review: one largest cryptocurrency exchanges binance offering 250 000 â¹1 6 crore worth cryptocurrency information would lead arrest hackers targeted last week exchange said also set aside 10 million future binance disclosed target large scale phishing stealing attempt
# Original summary: crypto exchange offers â¹1 6 cr bounty for arrest of hackers
# Predicted summary:  crypto exchange sues â¹1 crore for â¹1 crore
# score:  0.3436446393954861
#
#
# Review: supreme court monday directed j k government provide police protection family eight year old kathua rape murder victim counsel deepika rajawat counsel sunday alleged life danger adding threatened taking case trial eight accused began kathua today
# Original summary: sc orders protection for kathua rape victim family lawyer
# Predicted summary:  sc orders kathua rape case against kathua victim
# score:  0.5515605641153721
#
#
# Review: team india opener shikhar dhawan thursday took instagram share picture wife aesha wish birthday wish u happy birthday love great one thanks making life complete pillar family shikhar wrote shikhar tied knot aesha 2012
# Original summary: thanks for making life complete dhawan wishes wife on b'day
# Predicted summary:  dhawan shares pic with anushka wishes birthday
# score:  0.18612544500887301
#
#
# Review: sharing new trailer half brother ishaan khatter upcoming film 'beyond clouds' actor shahid kapoor wrote acting toh mein hai shahid wrote grow much directed iranian filmmaker majid majidi film also stars actress malavika mohanan scheduled release april 20
# Original summary: acting toh mein hai shahid on brother film trailer
# Predicted summary:  trailer of shahid ishaan khatter starrer 'dhadak' released
# score:  0.22062422564614886
#
#
# Review: trailer kajol riddhi sen starrer 'helicopter eela' released kajol plays protective cool mother joins son college spend time directed pradeep sarkar co produced ajay devgn film scheduled release september 7
# Original summary: trailer of kajol starrer 'helicopter eela' released
# Predicted summary:  trailer of kajol film 'helicopter eela' released
# score:  0.8571428571428571
#
#
# Review: canadian pm justin trudeau arrived india family saturday seven day state visit invitation pm narendra modi trudeau tour agra amritsar ahmedabad mumbai delhi tweeted visit aimed meeting government business leaders strengthening close friendship two nations
# Original summary: canada pm justin trudeau arrives in india with family
# Predicted summary:  canada pm modi to visit india to be in india
# score:  0.4
#
#
# Review: goldman sachs backed us mobile payments startup circle monday announced acquired cryptocurrency exchange circle disclose details deal reports suggested deal worth 400 million â¹2 600 crore founded 2014 within top 20 largest crypto exchanges trading volume
# Original summary: goldman sachs backed startup buys crypto exchange
# Predicted summary:  softbank to invest in startup
# score:  0.13406400920712788
#
#
# Review: university california moved federal appeals court patents issued broad institute affiliated mit harvard university controversy centres deserves credit gene editing technology crispr would also determine profit invention also believed lead nobel prize lead scientists
# Original summary: mit harvard fight in court over patents
# Predicted summary:  scientists use ai to detect patent for
# score:  0
#
#
# Review: liverpool forward mo salah awarded 2018 fifa award given best goal year monday 26 year old award solo goal liverpool city rivals everton receiving 38 fan votes real madrid forward gareth bale juventus forward cristiano ronaldo also contention bicycle kick goals last season
# Original summary: salah beats ronaldo bale to win fifa best goal of the year award
# Predicted summary:  manchester united manchester united barã§a win liverpool salah
# score:  0.13381535712974757
#
#
# Review: decade pluto lost planet status scientists noted planet claimed definition set international astronomical union planet said celestial body largest gravitational force orbit planet
# Original summary: should be as a planet scientists
# Predicted summary:  to be a planet in the planet
# score:  0.42857142857142855
#
#
# Review: filmmaker rohit shetty said sara ali khan approached directorial 'simmba' actress approached cooked brain messaging many times added speaking sara said messaged rohit sir thrice responded third message think king commercial cinema
# Original summary: nobody approached sara for simmba she approached us herself rohit
# Predicted summary:  i am not sara ali khan sara ali khan johar
# score:  0.10000000000000002
#
#
# Review: kangana ranaut talking pakistan pm waiting imran khan relations india pakistan said hope shed blood kind speech imran khan given nice really hope appeal really beautiful relationship added
# Original summary: hope there is no kangana on pak pm in waiting
# Predicted summary:  imran khan will be a great nation pakistan pm
# score:  0.09942659075715217
#
#
# Review: vodafone group aditya birla group thursday appointed sharma current coo vodafone india ceo merged idea cellular vodafone india kumar mangalam birla non executive chairman merged company cellular current cfo take cfo new entity merger
# Original summary: sharma named ceo of vodafone idea india entity
# Predicted summary:  vodafone idea ceo data scandal firm gets bail
# score:  0.375
#
#
# Review: test skipper tim paine aaron finch named australia odi t20i captains respectively ball tampering scandal paine lead odi side england finch vice captain series finch captain t20i team alongside wicketkeeper alex carey vice captain one t20i england t20i tri series zimbabwe
# Original summary: tim paine and finch named aus captains in odi and t20i
# Predicted summary:  paine abd was a odi cricket australia captain
# score:  0.17182231969774306
#
#
# Review: csk ambati rayudu hugged partner suresh raina leaving ground mix resulted run 79 37 srh sunday rayudu hit pacer siddarth kaul towards long tried steal second run kaul fumbled receiving throw raina stood ground rayudu fell short trying reach non striker end
# Original summary: rayudu hugs partner raina after getting run out for 79 37
# Predicted summary:  csk rayudu gets out for raina after getting run out
# score:  0.6333861926251716
#
#
# Review: indian shuttler saina nehwal beat thailand reach last four women singles event indonesia masters friday eighth seed saina reached semi final malaysia masters last week next face sixth seeded chinese meanwhile pv sindhu kidambi srikanth lost respective quarterfinal matches
# Original summary: saina nehwal enters indonesia masters semi finals
# Predicted summary:  saina nehwal wins india open semis
# score:  0.28216057496353797
#
#
# Review: cricket legends sachin tendulkar rahul dravid got stumped test careers spanning 200 164 matches respectively interestingly former batsmen got stumped bowling ex england spinner ashley giles turns 45 today tendulkar got 90 test 2001 dravid got 148 2002
# Original summary: sachin dravid got out just once in test
# Predicted summary:  sachin tendulkar 1st test squad for 1st time in india
# score:  0.3
#
#
# Review: former coal secretary hc gupta today sentenced three years jail delhi patiala house court coal scam case relating allotment coal blocks west bengal two bureaucrats k k c also awarded three year jail terms convicted persons patni anand mallick awarded four year jail terms
# Original summary: ex coal secretary hc gupta sentenced to 3 years in jail for scam
# Predicted summary:  ex sc judge jailed for 10 years in corruption case
# score:  0.2963272882726872
#
#
# Review: many seven people killed accident uttar pradesh ghaziabad friday child accidentally suv parked slope vehicle carrying wedding party around 12 people rolled gorge near highway groom father among killed
# Original summary: 7 killed in ghaziabad after child car
# Predicted summary:  3 killed as car falls into gorge in up in up
# score:  0.2727272727272727
#
#
# Review: us national security advisor john bolton said country need advice un international bodies govern defending decision withdraw un human rights council unhrc bolton added us opposed creation global body first place
# Original summary: we do not need un advice on how to us
# Predicted summary:  us will not be if it is not un haley
# score:  0.3
#
#
# Review: 30 year old man allegedly beheaded mother carried severed head police station tamil nadu sunday man used frequent mother property dispute reports said following argument mother day man killed sharp object surrendered police
# Original summary: man kills mother carries severed head to police station
# Predicted summary:  man kills mother for not abusing mother in tn
# score:  0.3333333333333333
#
#
# Review: addressing public rally vidisha congress president rahul gandhi said want share 'mann ki baat' instead hear 'mann ki baat' develop madhya pradesh added guaranteed congress going form government madhya pradesh state goes polls november 28
# Original summary: we want to hear your 'mann ki baat' develop mp says rahul
# Predicted summary:  rahul gandhi is a in the country rahul
# score:  0.07581633246407919
#
#
# Review: union bank india friday clarified 300 million around â¹1 crore exposure fraud transactions worth 1 77 billion detected punjab national bank recently bank however said fully confident receive payment light revelation union bank stock fell 1 25 friday markets closed
# Original summary: union bank has outstanding exposure to pnb fraud case
# Predicted summary:  sbi to pay â¹1 cr for indian banks reports
# score:  0.11111111111111109
#
#
# Review: billionaire elon musk responded harvard professor steven said building self driving tesla cars musk feared artificial intelligence tesla co founder said ai humanity deep trouble musk argued massive difference ai used car ai
# Original summary: elon musk trolls harvard prof over from remark
# Predicted summary:  musk tesla car to be a car in tesla car report
# score:  0.0909090909090909
#
#
# Review: court ruled indian pacer mohammed shami pay â¹80 000 per month instead â¹10 lakh monthly amount earlier demanded estranged wife hasin jahan family maintenance shami earlier refused pay maintenance amount demanded jahan citing fact commenced acting modelling
# Original summary: shami to pay wife â¹80 000 as maintenance instead of â¹10 lakh
# Predicted summary:  shami donates â¹4 lakh to son who asked to pay â¹1 lakh
# score:  0.3333333333333333
#
#
# Review: 31 year old tuition teacher shot dead monday inside coaching centre unknown assailants delhi area deceased sister said brother killed alleged love affair student muslim girl according reports student brother opposed relationship due religion
# Original summary: delhi teacher shot dead over alleged affair with muslim girl
# Predicted summary:  man kills self after mom kills self in delhi
# score:  0.09942659075715217
#
#
# Review: head 2018 fifa world cup local organising committee loc alexey revealed security stopped 170 people running onto pitches tournament four members riot protest group managed invade pitch world cup final july 15 fined jailed 15 days incident
# Original summary: 2018 fifa world cup saw 170 pitch attempts organisers
# Predicted summary:  wc winning world cup final to be held in
# score:  0.2222222222222222
#
#
# Review: amid ongoing protests dalit organisations alleged dilution sc st protection act supreme court congress president rahul gandhi said keeping dalits bottom dna bjp rss thousands dalit brothers sisters streets demanding rights modi government salute added
# Original summary: keeping dalits at the is in dna of bjp rss rahul
# Predicted summary:  rahul gandhi is a muslim bjp chief
# score:  0.24202205228903967
#
#
# Review: indian man racially abused canada parking dispute white woman told go back country called p ki sh coloured skin woman also spit man car called loser calling incident disturbing man said i've never experienced anything like
# Original summary: p ki with t skin indian faces racism in canada
# Predicted summary:  indian origin man jailed for calling woman on flight
# score:  0.09942659075715217
#
#
# Review: former pakistan pm nawaz sharif wife begum kulsoom nawaz come month long coma sharif family said kulsoom nawaz undergoing treatment london unconscious since suffered cardiac arrest last month sharif daughter maryam return pakistan friday face prison sentence avenfield corruption case
# Original summary: ex pak pm nawaz sharif wife comes out of month long coma
# Predicted summary:  ex pak pm nawaz sharif wife to get married in hospital
# score:  0.4980549361539613
#
#
# Review: west bengal cm mamata banerjee equated bjp tripura assembly elections win winning municipal elections tripura cm biplab deb said mamata didi get brain examined hospital constitution treats states equal six feet three inches tall five feet human added
# Original summary: mamata didi should get her brain tripura cm
# Predicted summary:  mamata calls for mamata
# score:  0.09196986029286058
#
#
# Review: tibetan government exile product 'make india' campaign tibetan pm said 'thank india' event commemorating dalai lama 60 year exile event attended bjp general secretary ram madhav despite reports centre cautioned indian leaders stay away tibetan events due sensitive relations china
# Original summary: tibetan govt in a product of make in india tibet pm
# Predicted summary:  india to be pm modi in 2019
# score:  0.24202205228903967
#
#
# Review: actor anupam kher honoured distinguished fellow award 3rd india global summit held mit school management boston great honour pride accept distinguished fellow award i'm grateful india global recognising work continue represent great nation good work said anupam
# Original summary: anupam honoured with fellow award in
# Predicted summary:  anupam kher to perform at india at oscars 2018
# score:  0.11111111111111109
#
#
# Review: nda candidate harivansh narayan singh jd u elected rajya sabha deputy chairman thursday pm narendra modi said hari congratulating newly elected deputy chairman pm modi added blessed talent writing also favourite former pm chandra shekhar ji
# Original summary: now we are all pm on rs dy chairman election
# Predicted summary:  pm modi should not be a pm in 2019 lok sabha polls
# score:  0.08333333333333333
#
#
# Review: government revised fdi policy e commerce sector amazon may sell stake cloudtail large seller amazon marketplace platform new norms bar online retailers selling products entities stake cloudtail joint venture amazon infosys founder narayana murthy ventures
# Original summary: amazon may have to sell stake after india new rules
# Predicted summary:  amazon may sell amazon stake in amazon report
# score:  0.38940039153570244
#
#
# Review: russian model jumped 6th floor dubai hotel escape rape refused sex us businessman model survived fall broke spine businessman threatened knife forced detained airport trying flee country
# Original summary: russian model jumps off 6th floor to escape rape survives
# Predicted summary:  russian woman gets into car in space station
# score:  0.09735009788392564
#
#
# Review: addressing sabha tuesday uttar pradesh cm yogi adityanath said hindu reason celebrate eid government would continue work peaceful celebration eid cm added comes days asked planning celebrate eid celebrating holi vrindavan
# Original summary: i am a hindu have no reason to celebrate eid up cm yogi
# Predicted summary:  lord ram will be up cm yogi adityanath
# score:  0.20072303569462135
#
#
# Review: residents us city maine witnessing ice disk phenomenon measuring 100 metres across freezing river water flows slowly main current likely freeze creating disc spin melt melting water spins sinks scientists said
# Original summary: 100 metre wide ice surfaces in us river
# Predicted summary:  us to get its own statue of water in water
# score:  0.2
#
#
# Review: indians account 75 highly skilled professionals waiting obtain legal permanent residence status us popularly known green card 395 025 foreign nationals waiting green card 306 601 indians according official data may country 10 000 people waiting green card china 67
# Original summary: indians account for over 75 of us green card waiting list
# Predicted summary:  india to get its own papers in us
# score:  0.08591115984887154
#
#
# Review: dmk president karunanidhi friday became first indian political figure lead party 50 years elected dmk chief july 27 1969 94 year old leader served chief minister tamil nadu five times however health started deteriorating son mk stalin appointed dmk working president 2017
# Original summary: dmk karunanidhi becomes first to lead a party for 50 yrs
# Predicted summary:  dmk chief karunanidhi becomes first dmk chief
# score:  0.32269606971871956
#
#
# Review: japanese economy posted longest period growth since 1980s boom government data showed wednesday world third largest economy expanded rate 0 5 fourth quarter 2017 eighth straight quarter expansion growth mainly due increased consumer spending accounts two thirds country gdp
# Original summary: japan economy posts longest growth streak since
# ...
# Original summary: contest makes startups pitch to investors in water
# Predicted summary:  startup makes ai startup to make water
# score:  0.37151909989293497
#
#
# Review: ndtv sued anil ambani reliance â¹10 000 crore ahmedabad court channel coverage india france rafale jet deal ceo singh tweeted thursday per ndtv reliance filed lawsuit weekly show truth vs hype aired september 29 debated reliance partnership dassault
# Original summary: says sued for â¹10 000 crore by reliance over rafale coverage
# Predicted summary:  rcom files crore deal with rafale deal to rafale deal
# score:  0.18096748360719192
#
#
# Review: google allowing users comment search results according report uncovered feature googleâs latest beta app visible public searches live games users view comments page comments well
# Original summary: google to allow users to comment on search results report
# Predicted summary:  google to launch search for its service
# score:  0.2791881675133095
#
#
# Review: responding australian captain tim paine changing mumbai comment indian batsman rohit sharma said paine gets hundred ask boss mumbai indians buy india first innings melbourne test paine taunted rohit sharma saying would support mumbai indians rohit hit six
# Original summary: if tim paine gets ton we will buy him for mumbai indians rohit sharma
# Predicted summary:  rohit sharma paine mumbai mumbai captain rohit sharma
# score:  0.23618327637050734
#
#
# Review: supreme court thursday refused give urgent hearing karti chidambaram request travel abroad november 3 saying go stay back india karti matter taken tomorrow karti probed allegedly obtaining foreign investment clearances aircel maxis deal inx media father p chidambaram finance minister
# Original summary: stay back in india sc denies urgent hearing for karti chidambaram
# Predicted summary:  sc refuses to hear plea on rafale deal with india
# score:  0.18096748360719192
#
#
# Review: 20 year old bengaluru man set mother ablaze denied giving money accused reportedly got heated argument mother money mother reportedly refused give money thinking would spend alcohol angered denial man threw petrol set ablaze
# Original summary: bengaluru man sets mother ablaze after she denies him money
# Predicted summary:  man kills mother for not giving money to mother
# score:  0.2982797722714565
#
#
# Review: indian men shooting team senior shotgun coach singh said government recognise efforts indian coaches consider increasing salary lure money come play many us might well start coaching squads countries singh added said coaches selfless service
# Original summary: time for govt to recognise our efforts indian shooting coach
# Predicted summary:  india to be a issue of the time in india
# score:  0.2
#
#
# Review: indian equity benchmark sensex closed 622 points lower day high monday registered longest losing streak three months sensex fell 332 points settle 38 312 nse nifty 50 index settled 11 600 levels 11 582 98 points rupee hit fresh lifetime low 71 21 dollar
# Original summary: sensex falls over 600 points from day high on monday
# Predicted summary:  sensex falls points nifty ends below 10 000 mark
# score:  0.2982797722714565
#
#
# Review: teenage girl allegedly dragged jungle gangraped four miscreants west district jharkhand police said wednesday four accused also assaulted two friends police added police team later found girl jungle arrested four accused including minor
# Original summary: teenage girl dragged into gangraped in jharkhand
# Predicted summary:  girl raped by 3 men in bihar
# score:  0.2857142857142857
#
#
# Review: addressing gathering indonesia wednesday prime minister narendra modi said many may never india invite come india kumbh next year talking ties two nations said india indonesia tied cultural relationship old bond
# Original summary: i invite you all to attend kumbh next year pm in indonesia
# Predicted summary:  india will be india to india pm modi
# score:  0.15163266492815836
#
#
# Review: formula one driver charles leclerc drives formula one team survived spin german grand prix sunday leclerc car took spin driving turn 1 grand prix witnessed rainy conditions saw german champion sebastian vettel crash race following safety car deployed
# Original summary: formula one driver survives spin during grand race
# Predicted summary:  f1 driver crashes out of car in race 3 minutes
# score:  0.2
#
#
# Review: 99 year old australian swimmer broke world record 100 104 age category 50m freestyle wednesday george turns 100 april completed 50m freestyle 56 12 seconds surpassing previous record 1 16 92 set late canadian swimmer 2009 took swimming seriously turned 80
# Original summary: 99 year old in 56 12 sec to break world record
# Predicted summary:  man sets record record of most successful in world
# score:  0.26691246763893595
#
#
# Review: actress tabu talking equation ajay devgn said working feel like work known since time even part industry added tabu said like around people lot enjoy working ajay
# Original summary: when i am working with ajay it does not feel like work tabu
# Predicted summary:  i am not a star in the film industry devgn
# score:  0.22224546620451535
#
#
# Review: video showing groom shot dead alleged celebratory firing uttar pradesh lakhimpur district sunday surfaced video shows accused purportedly close friend groom firing two shots second hits groom immediately rushed hospital succumbed gunshot wound
# Original summary: video groom shot dead by friend during celebratory firing
# Predicted summary:  video shows mob attack on man shot dead in up
# score:  0.3
#
#
# Review: gurugram based grocery delivery startup milkbasket raised 7 million extended series funding round led us based venture capital firm mayfield fund existing investors including kalaari capital unilever ventures also participated round founded 2015 milkbasket subscription based service delivers grocery milk daily doorstep top basis
# Original summary: grocery startup raises 7 mn in funding
# Predicted summary:  bengaluru based startup raises 1 million
# score:  0.28216057496353797
#
#
# Review: delhi university miranda house retained position india best college national institutional ranking framework released human resource development ministry tuesday du st stephen college bishop college tamil nadu secured second third ranks respectively du hindu college ranked fourth presidency college chennai ranked fifth
# Original summary: which are the top colleges in india
# Predicted summary:  delhi university releases national anthem for schools
# score:  0
#
#
# Review: india signed 950 million deal russia buy two admiral class guided missile frigates service navy reports said frigates used anti surface warfare anti submarine warfare anti air warfare missions earlier india inked 5 billion deal buy 400 missile system russia despite threats us sanctions defence trade russia
# Original summary: india deal with russia to buy 2 report
# Predicted summary:  india to buy russia for its first missile sanctions
# score:  0.4444444444444444
#
#
# Review: several people feared dead us bangla airlines plane crashed landing international airport kathmandu nepal monday aircraft carrying 67 passengers 4 crew members reportedly skidded runway caught fire operations halted airport rescue teams deployed
# Original summary: bangladesh plane carrying 71 people crashes at nepal airport
# Predicted summary:  us airport plane crashes into plane on plane
# score:  0.3309363384692233
#
#
# Review: engineering conglomerate l group chairman naik wednesday appointed chairman national skill development corporation oversees government short term skill development programmes including pradhan mantri kaushal vikas yojana functioning without full time chairman since resignation previous chairman november 2016
# Original summary: l t chairman am naik to head national development
# Predicted summary:  ias officer appointed governor of
# score:  0
#
#
# Review: ahead england tour australia new coach justin langer said australia sledging actually good word fun part game difference banter abuse abuse good captain tim paine explained team would sledge opposition make uncomfortable abuse longer part australia methods
# Original summary: sledging is a fun part of the game aus coach justin langer
# Predicted summary:  paine and i do not like a sex with aus coach langer
# score:  0.3333333333333333
#
#
# Review: us president donald trump submitted written responses questions special counsel robert mueller probe russian meddling 2016 presidential elections alleged collusion trump campaign trump responded several questions including knowledge campaign members' contact russians trump repeatedly denied collusion russians
# Original summary: trump gives written answers to russia meddling probe questions
# Predicted summary:  trump denies probe to testify in russia probe report
# score:  0.4444444444444444
#
#
# Review: saif ali khan served legal notice interpol regards wild hunting case bulgaria bulgarian police recently booked agent allegedly organised hunt without permits licences per reports saif statement recorded police month ago
# Original summary: saif gets notice from interpol for hunting wild in
# Predicted summary:  saif ali khan to be booked for killing in delhi
# score:  0.3
#
#
# Review: ministry external affairs wednesday denied reports west bengal chief minister mamata banerjee given permission attend event vivekananda vedanta society chicago receive request clearance regarding visit said ministry spokesperson earlier mamata said could go unholy conspiracy hatched certain people nn
# Original summary: did not receive any request for mamata chicago visit mea
# Predicted summary:  india will be mamata on west bengal cm mamata
# score:  0.09942659075715217
#
#
# Review: six foot long python died wednesday allegedly tortured locals mistreated click selfies west bengal birbhum though forest department staff went spot snake died could rescued trying find manhandled python divisional forest officer hari krishnan said
# Original summary: dies after being by selfie seekers
# Predicted summary:  12 dead after fire breaks out in west bengal
# score:  0.11111111111111109
#
#
# Review: rti reply revealed karnataka government spent â¹43 lakh cm hd kumaraswamy seven minute swearing ceremony andhra pradesh cm chandrababu naidu stay bengaluru taj west end hotel reportedly cost highest â¹8 3 lakh delhi cm arvind kejriwal samajwadi party chief akhilesh yadav bsp chief mayawati also hotel bills â¹1 lakh
# Original summary: lakh spent for karnataka cm 7 min oath ceremony rti
# Predicted summary:  andhra cm kejriwal to appear together on cyclone gaja
# score:  0.09942659075715217
#
#
# Review: fox news named scott first ever female ceo roger ousted ceo 2016 amid sexual harassment allegations scott lead fox news fox business network scott worked fox news since inception nearly 22 years ago recently president programming fox news fox business
# Original summary: fox news names first female ceo after sexual harassment row
# Predicted summary:  female ceo sues facebook over sexual harassment row
# score:  0.48675048941962806
#
#
# Review: rape allegations levelled portugal footballer cristiano ronaldo led 5 fall price shares new club juventus accusations levelled former real madrid player sports firm nike expressed matter stated closely monitoring situation
# Original summary: juventus' shares fall 5 after rape allegations against ronaldo
# Predicted summary:  ronaldo is not a real madrid captain
# score:  0.10735389901075512
#
#
# Review: india singles player wimbledon 2018 pocket around â¹35 lakh losing first round tournament monday apart lost italy thomas four sets six indians participating wimbledon doubles tournament year edition
# Original summary: only indian in wimbledon singles earns â¹35 lakh on 1st rd loss
# Predicted summary:  wimbledon to play in india for 1st time in the first ever
# score:  0.25
#
#
# Review: first crew members aboard international space station took part badminton tournament japan kanai russia anton shkaplerov teamed russia alexander misurkin us' mark vande replaced compatriot joseph acaba activities useful psychological relaxation strengthening friendly relations team said mark
# Original summary: astronauts play badminton in zero on space station
# Predicted summary:  1st to launch its first ever rocket in us
# score:  0.11111111111111109
#
#
# Review: expressing grief late pm atal bihari vajpayee demise pakistan pm designate imran khan said stand india difficult time void politics south asia death political differences desire peace remains present across border added pakistan government also released statement extending condolences
# Original summary: with india in this difficult time imran on vajpayee demise
# Predicted summary:  pak pm vajpayee was not an indian peace pak pm
# score:  0.10000000000000002
#
#
# Review: government friday announced padma bhushan former isro scientist nambi narayanan cleared 1994 spying case supreme court last year narayanan wrongly accused sharing defence secrets maldivian spies also awarded â¹50 lakh compensation kerala government sc stated unnecessarily arrested harassed state police
# Original summary: framed in isro spy case awarded padma bhushan
# Predicted summary:  ex isro scientist who convicted of sexual harassment
# score:  0.12500000000000003
#
#
# Review: bombay high court thursday adjourned hearing kotak mahindra bank petition reserve bank india rbi promoter stake reduction march 12 rbi sought time file reply bank petition uday kotak led bank barred reducing promoter holding mandated level preference share sale
# Original summary: bombay hc to hear plea on stake in march
# Predicted summary:  rbi allows rbi to stop payments bank ceo
# score:  0.11031211282307446
#
#
# Review: video labrador touted world first ice skating dog gone viral owner 56 year old del adopted dog rescued utah shelter euthanasia list learnt skating custom made blades along jersey stick
# Original summary: dog rescued from kill shelter learns ice video goes viral
# Predicted summary:  video shows world goes viral
# score:  0.2207276647028654
#
#
# Review: bank tuesday reported 23 8 year year increase profit â¹1 72 june quarter bank net interest income rose 19 6 year year â¹2 122 43 crore quarter percentage total loans gross bad loans fell 1 15 compared 1 17 march quarter n
# Original summary: bank profit rises 24 to â¹1 cr in june quarter
# Predicted summary:  bank profit rises 10 to crore in june quarter
# score:  0.6959861353000654
#
#
# Review: pakistan minister information broadcasting fawad chaudhry thursday said country would send pakistani astronaut space first time 2022 agreement pakistan space agency chinese company already signed minister added earlier year pakistan launched two indigenously built satellites orbit using chinese launch vehicle
# Original summary: pak to send its 1st astronaut to space in 2022 with china help
# Predicted summary:  pak minister calls for talks with india
# score:  0.12124938447912854
#
#
# Review: accusing congress attacking bus stones monday madhya pradesh cm shivraj singh chouhan said party blood black flags also waved chouhan state wide tour ahead assembly elections eight suspected congress leaders arrested following incident
# Original summary: congress for my blood mp cm after attack on his bus
# Predicted summary:  congress leader calls for congress mp cm
# score:  0.32269606971871956
#
#
# Review: court kerala granted bail bjp leader k surendran 71 others arrested allegedly flouting prohibitory orders near sabarimala temple court set bail conditions barring entering limit sabarimala temple located two months also turned surendran request offer prayers lord ayyappa shrine
# Original summary: bjp leader 71 others arrested near sabarimala granted bail
# Predicted summary:  bjp leader who led to sabarimala arrested
# score:  0.4294155960430205
